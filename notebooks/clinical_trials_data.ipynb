# %%
import pandas as pd
import requests
import json
import io
import xml.etree.ElementTree as ET

# %%
data = pd.read_csv("../data/drugs.txt", sep="\t", low_memory=False)

# %%
data['Highest Development Phase'].value_counts()
# Out:
# No development reported (Preclinical)        422
# Discontinued (Preclinical)                   240
# Discontinued (II)                            196
# Marketed                                     191
# Preclinical                                  171
# Phase II                                     133
# No development reported (I)                  117
# Discontinued (I)                             105
# No development reported (Research)            77
# Phase I                                       76
# Research                                      76
# No development reported (II)                  43
# Discontinued (III)                            43
# Phase III                                     42
# Phase Unknown                                 19
# Clinical Phase Unknown                        15
# No development reported (Clinical)            14
# Preregistration                               14
# Phase I/II                                    14
# No development reported (III)                 12
# Discontinued (Preregistration)                12
# Discontinued (Clinical)                       11
# Registered                                    11
# Discontinued                                   9
# No development reported                        9
# Discontinued (Research)                        9
# Discontinued (I/II)                            7
# Market Withdrawal                              5
# Suspended (II)                                 4
# No development reported (I/II)                 4
# Phase II/III                                   4
# Discontinued (II/III)                          4
# Suspended (Preclinical)                        4
# No development reported (Preregistration)      4
# Suspended (I)                                  3
# No development reported (Registered)           3
# No development reported (0)                    3
# Discontinued (Registered)                      2
# Suspended (Research)                           1
# Suspended (III)                                1
# Name: Highest Development Phase, dtype: int64

# %%
drug_list = data[data['Highest Development Phase'].str.contains("Phase")]["Drug Name"]

# %%
drug_list
# Out:
# 0                    Ganaxolone - Marinus Pharmaceuticals
# 4                                                 STR 324
# 6                       Nicotinamide riboside - ChromaDex
# 7                                                AMG 0101
# 9                                                KAND 567
#                               ...
# 1455    Buprenorphine/naloxone - Aoxing Pharmaceutical...
# 1462         Doxepin intranasal - Winston Pharmaceuticals
# 1468                                  Danazol transdermal
# 1478                                              NXN 188
# 1483                       Morphine-6-glucuronide - PAION
# Name: Drug Name, Length: 303, dtype: object

# %% [markdown]
# ## List of drugs from R

# %%
drug_list = pd.read_csv("../data/drug_list_20210503.csv")

# %%
drug_list = list(drug_list.transpose().values.flatten())

# %% [markdown]
# ## Fields available per drug on clinical trials

# %%
fields = requests.get("https://clinicaltrials.gov/api/info/study_fields_list")

# %%
tree = ET.parse(io.StringIO(fields.text))

# %%
fieldlist = []
for i in tree.find('FieldList'):
    fieldlist.append(i.items()[0][1])

print(fieldlist)
print(len(fieldlist))
# Out:
# ['Acronym', 'AgreementOtherDetails', 'AgreementPISponsorEmployee', 'AgreementRestrictionType', 'AgreementRestrictiveAgreement', 'ArmGroupDescription', 'ArmGroupInterventionName', 'ArmGroupLabel', 'ArmGroupType', 'AvailIPDComment', 'AvailIPDId', 'AvailIPDType', 'AvailIPDURL', 'BaselineCategoryTitle', 'BaselineClassDenomCountGroupId', 'BaselineClassDenomCountValue', 'BaselineClassDenomUnits', 'BaselineClassTitle', 'BaselineDenomCountGroupId', 'BaselineDenomCountValue', 'BaselineDenomUnits', 'BaselineGroupDescription', 'BaselineGroupId', 'BaselineGroupTitle', 'BaselineMeasureCalculatePct', 'BaselineMeasureDenomCountGroupId', 'BaselineMeasureDenomCountValue', 'BaselineMeasureDenomUnits', 'BaselineMeasureDenomUnitsSelected', 'BaselineMeasureDescription', 'BaselineMeasureDispersionType', 'BaselineMeasureParamType', 'BaselineMeasurePopulationDescription', 'BaselineMeasureTitle', 'BaselineMeasureUnitOfMeasure', 'BaselineMeasurementComment', 'BaselineMeasurementGroupId', 'BaselineMeasurementLowerLimit', 'BaselineMeasurementSpread', 'BaselineMeasurementUpperLimit', 'BaselineMeasurementValue', 'BaselinePopulationDescription', 'BaselineTypeUnitsAnalyzed', 'BioSpecDescription', 'BioSpecRetention', 'BriefSummary', 'BriefTitle', 'CentralContactEMail', 'CentralContactName', 'CentralContactPhone', 'CentralContactPhoneExt', 'CentralContactRole', 'CollaboratorClass', 'CollaboratorName', 'CompletionDate', 'CompletionDateType', 'Condition', 'ConditionAncestorId', 'ConditionAncestorTerm', 'ConditionBrowseBranchAbbrev', 'ConditionBrowseBranchName', 'ConditionBrowseLeafAsFound', 'ConditionBrowseLeafId', 'ConditionBrowseLeafName', 'ConditionBrowseLeafRelevance', 'ConditionMeshId', 'ConditionMeshTerm', 'DelayedPosting', 'DesignAllocation', 'DesignInterventionModel', 'DesignInterventionModelDescription', 'DesignMasking', 'DesignMaskingDescription', 'DesignObservationalModel', 'DesignPrimaryPurpose', 'DesignTimePerspective', 'DesignWhoMasked', 'DetailedDescription', 'DispFirstPostDate', 'DispFirstPostDateType', 'DispFirstSubmitDate', 'DispFirstSubmitQCDate', 'EligibilityCriteria', 'EnrollmentCount', 'EnrollmentType', 'EventGroupDeathsNumAffected', 'EventGroupDeathsNumAtRisk', 'EventGroupDescription', 'EventGroupId', 'EventGroupOtherNumAffected', 'EventGroupOtherNumAtRisk', 'EventGroupSeriousNumAffected', 'EventGroupSeriousNumAtRisk', 'EventGroupTitle', 'EventsDescription', 'EventsFrequencyThreshold', 'EventsTimeFrame', 'ExpAccTypeIndividual', 'ExpAccTypeIntermediate', 'ExpAccTypeTreatment', 'ExpandedAccessNCTId', 'ExpandedAccessStatusForNCTId', 'FDAAA801Violation', 'FlowAchievementComment', 'FlowAchievementGroupId', 'FlowAchievementNumSubjects', 'FlowAchievementNumUnits', 'FlowDropWithdrawComment', 'FlowDropWithdrawType', 'FlowGroupDescription', 'FlowGroupId', 'FlowGroupTitle', 'FlowMilestoneComment', 'FlowMilestoneType', 'FlowPeriodTitle', 'FlowPreAssignmentDetails', 'FlowReasonComment', 'FlowReasonGroupId', 'FlowReasonNumSubjects', 'FlowReasonNumUnits', 'FlowRecruitmentDetails', 'FlowTypeUnitsAnalyzed', 'Gender', 'GenderBased', 'GenderDescription', 'HasExpandedAccess', 'HealthyVolunteers', 'IPDSharing', 'IPDSharingAccessCriteria', 'IPDSharingDescription', 'IPDSharingInfoType', 'IPDSharingTimeFrame', 'IPDSharingURL', 'InterventionAncestorId', 'InterventionAncestorTerm', 'InterventionArmGroupLabel', 'InterventionBrowseBranchAbbrev', 'InterventionBrowseBranchName', 'InterventionBrowseLeafAsFound', 'InterventionBrowseLeafId', 'InterventionBrowseLeafName', 'InterventionBrowseLeafRelevance', 'InterventionDescription', 'InterventionMeshId', 'InterventionMeshTerm', 'InterventionName', 'InterventionOtherName', 'InterventionType', 'IsFDARegulatedDevice', 'IsFDARegulatedDrug', 'IsPPSD', 'IsUSExport', 'IsUnapprovedDevice', 'Keyword', 'LargeDocDate', 'LargeDocFilename', 'LargeDocHasICF', 'LargeDocHasProtocol', 'LargeDocHasSAP', 'LargeDocLabel', 'LargeDocTypeAbbrev', 'LargeDocUploadDate', 'LastKnownStatus', 'LastUpdatePostDate', 'LastUpdatePostDateType', 'LastUpdate ...
# 322

# %%
def get_clinical_trials_data(drugname, fields):
    query0 = "https://clinicaltrials.gov/api/query/study_fields?expr="
    query1 = "&fmt=csv&field=InterventionName&fields="
    
    response = requests.get(query0 + drugname + query1 + fields)
    # find location of empty line; data follows that
    posn = response.text.find("\n\n")
    df = pd.read_csv(io.StringIO(response.text[posn+2:]))
    if df.empty:
        print(f'{drugname} not found')
        pass
    else:
        df['Name'] = drugname
        return df

# %%
fields = "OverallStatus,Condition,Phase,LastUpdatePostDate,StudyType,BriefSummary"

# test
get_clinical_trials_data('AV 101', fields).shape
get_clinical_trials_data('XEN 2174', fields)
# Out:
# XEN 2174 not found

# %%
clinical_trials_df = []

for name in drug_list:
    ctdf = get_clinical_trials_data(name, fields)
    clinical_trials_df.append(ctdf)

clinical_trials_df = pd.concat(clinical_trials_df)
# Out:
# Tramadol - Aytu BioPharma not found
# Oxycodone/promethazine - Charleston Laboratories not found
# Buprenorphine sublingual - Benuvia Therapeutics not found
# Buprenorphine/naloxone sublingual - Benuvia Therapeutics not found
# Oxycodone hydrochloride - SpecGx not found
# Diclofenac - Benuvia Therapeutics not found
# Zonisamide - Eisai Co Ltd not found
# PTI 555 not found
# Dextromethadone - Cornell University/Relmada Therapeutics not found
# Tramadol controlled release - e-Therapeutics not found
# Tramadol orodispersible - Ethypharm not found
# Oxycodone controlled release - Teikoku Seiyaku not found
# JNJ 38488502 not found
# Fentanyl intranasal spray - Kyowa Kirin International not found
# Oxycodone controlled release - Cassava Sciences not found
# Efipladib not found
# Nitroglycerin topical - Kyowa Kirin International not found
# Capsaicin dermal patch - Grunenthal not found
# Rufinamide - Novartis not found
# Memantine - Children's Medical Center Corporation/Merz Pharma not found
# Eliapixant - Bayer not found
# Celecoxib - Astellas Pharma/Pfizer not found
# Esreboxetine - Axsome Therapeutics not found
# Valnivudine - Hepion Pharmaceuticals not found
# Dronabinol/palmitoylethanolamide - SciSparc not found
# CYT 1010 not found
# Nabilone controlled release - AOP Orphan Pharmaceuticals not found
# Liquid filled aspirin capsule - PLx Pharma not found
# CMX 020 not found
# ZTL 103 not found
# Cannabidiol - ANANDA Scientific not found
# Relugolix - Myovant/Takeda not found
# Buprenorphine - Relmada Therapeutics not found
# Oxymorphone transdermal - Avecho Biotechnology not found
# Oxycodone/naloxone sustained release - Shandong Luye Pharmaceutical not found
# Fentanyl - Alexza Pharmaceuticals/Lee's Pharmaceutical not found
# Hydromorphone transdermal - Altea Therapeutics not found
# NCX 701 not found
# Hydrocodone/paracetamol/alvimopan not found
# CEP 28190 not found
# Anpirtoline not found
# Buprenorphine transdermal - Samyang not found
# Tramadol controlled release - Toray not found
# Tramadol - TheraQuest Biosciences not found
# ONO 8711 not found
# OT 7100 not found
# Morphine - Ethypharm not found
# LAS 34475 not found
# WAY 195725 not found
# Butorphanol intranasal not found
# Fentanyl transdermal - Acrux not found
# M 40419 not found
# VANH 36 not found
# CGX 1160 not found
# Prosaptide TX14 A not found
# GPI 5693 not found
# Devazepide not found
# Dextromethorphan/methadone - Endo not found
# MH 15E not found
# BMS 347070 not found
# CGX 1007 not found
# ADL 21294 not found
# Fentanyl transdermal - 3M Drug Delivery Systems/Purdue Pharma not found
# CO 102862 not found
# CJC 1008 not found
# Morphine/lidocaine topical spray - EpiCept not found
# Clonidine gel - Curatek Pharmaceuticals not found
# Morphine inhalation - Aradigm Corporation not found
# BL 1832 not found
# BL 1834 not found
# JTC 801 not found
# NGX 5020 not found
# Fentanyl inhalation - Aradigm Corporation not found
# DPI 3290 not found
# RO 158081 not found
# Morphine/dextromethorphan - Endo not found
# ADL 100116 not found
# AZD 4282 not found
# AM 336 not found
# Ultramorph not found
# Fentanyl iontophoretic - Fournier not found
# Morphine-6-glucuronide - ML Laboratories not found
# ReN 1869 not found
# Remacemide not found
# CP 122721 not found
# Tilmacoxib not found
# Butorphanol-intranasal - Nastech not found
# GR 79236 not found
# SR 144190 not found
# GV 196771 not found
# Licostinel not found
# Davasaicin not found
# Diclofenac rectal - CeNeS not found
# BL 1827 not found
# Dapitant not found
# Latranal not found
# S 8115 not found
# T 3788 not found
# Dynorphin A not found
# GW 275919 not found
# Lanepitant not found
# Vedaclidine not found
# ZD 9379 not found
# GR 253035 not found
# Diclofenac digolil not found
# ONO 9902 not found
# Tilnoprofen arbamel not found
# Trefentanil not found

# %% [markdown]
# ## Check what drugs we got data for

# %%
returned_names = list(clinical_trials_df['Name'].unique())

# %%
len(drug_list)
# Out:
# 431

# %% [markdown]
# ## Names of drugs with no data on clinical trials

# %%
drugs_with_no_info = list(set(drug_list) ^ set(returned_names))

# %%
drugs_with_no_info
# Out:
# ['Oxymorphone transdermal - Avecho Biotechnology',
#  'Buprenorphine implant - Molteni/Titan Pharmaceuticals',
#  'BMS 347070',
#  'Cannabinol Topical - InMed Pharmaceuticals',
#  'Levacecarnine',
#  'Fentanyl patch - Kyukyu Pharmaceutical/Maruishi Pharmaceutical',
#  'AM 336',
#  'Paracetamol intravenous - Bristol-Myers Squibb/Mallinckrodt',
#  'Nabilone controlled release - AOP Orphan Pharmaceuticals',
#  'Flupirtine - Synthetic Biologics',
#  'GR 253035',
#  'Butibufen',
#  'Tramadol intravenous - Revogenex/Avenue Therapeutics',
#  'Morphine - Ethypharm',
#  'Fentanyl intranasal spray - Kyowa Kirin International',
#  'Morphine buccal - Generex Biotechnology',
#  'Tramadol controlled release - Toray',
#  'Oxycodone transdermal - Avecho Biotechnology',
#  'Abuse resistant oxycodone immediate release - Inspirion Delivery Sciences',
#  'Tilidine - Aoxing',
#  'Tapentadol intranasal - Torrent Pharmaceuticals',
#  'Cannabidiol/tetrahydrocannabinol - AusCann',
#  'Fentanyl transdermal - Altea Therapeutics',
#  'GR 79236',
#  'PTI 501',
#  'Capsaicin dermal patch - Grunenthal',
#  'Diclofenac/tramadol - AbbVie',
#  'Esreboxetine - Axsome Therapeutics',
#  'Zonisamide - Eisai Co Ltd',
#  'ALKS 7106',
#  'Buprenorphine - Faran Shirin',
#  'Abuse resistant morphine extended release - Inspirion Delivery Technologies',
#  'ADL 21294',
#  'Diclofenac - Assertio Therapeutics',
#  'Fadolmidine',
#  'Paracetamol - AYUMI Pharma',
#  'Oxycodone controlled release - Teikoku Seiyaku',
#  'Fentanyl iontophoretic - Fournier',
#  'Devazepide',
#  'Mavatrep',
#  'BL 1827',
#  'Hydrocodone/chlorpheniramine - Currax Pharmaceuticals',
#  'CO 102862',
#  'Dynorphin A',
#  'Asalhydromorphone - KemPharm',
#  'Buprenorphine sublingual - Benuvia Therapeutics',
#  'Buprenorphine - Relmada Therapeutics',
#  'Tilmacoxib',
#  'S 8115',
#  'Morphine/dextromethorphan - Endo',
#  'Tebanicline',
#  'Pregabalin controlled release - Alvogen Korea',
#  'Efipladib',
#  'Hydrocodone controlled release - DURECT Corporation',
#  'M 40419',
#  'NCX 701',
#  'Danazol transdermal',
#  'Diclofenac digolil',
#  'Metenkefalin/tridecactide - Farmacija',
#  'Rezatomidine',
#  'Butorphanol-intranasal - Nastech',
#  'CYT 1010',
#  'CMX 020',
#  'Hydrocodone extended release - Assertio Therapeutics',
#  'Morphine oral - Elan Corporation',
#  'Oxycodone extended release - Assertio Therapeutics',
#  'Fentanyl controlled-release - Onxeo',
#  'Morphine/lidocaine topical spray - EpiCept',
#  'Pregabalin controlled release - GL PharmTech',
#  'Morphine extended release - Assertio Therapeutics',
#  'Lanepitant',
#  'Hydromorphone extended release - Ensysce Biosciences',
#  'Tramadol - Athena Bioscience',
#  'LAS 34475',
#  'Remacemide',
#  'Eliapixant - Bayer',
#  'ADL 100116',
#  'Ketorolac sublingual - Orexo',
#  'PTI 555',
#  'CTP 354',
#  'OT 7100',
#  'Fentanyl transdermal - Acrux',
#  'WAY 195725',
#  'GV 196771',
#  'Parentide - DiverDrugs',
#  'Oxycodone/dextromethorphan - Endo',
#  'Latranal',
#  'Frakefamide',
#  'Oxycodegol - Nektar Therapeutics',
#  'AZD 4282',
#  'Fentanyl transdermal - Hisamitsu',
#  'Hydrocodone controlled-release - Purdue Pharma',
#  'AGN 209323',
#  'Paracetamol extended release - Altus Formulation',
#  'Morphine injection - BD Rx',
#  'Hydrocodone/chlorphenamine extended-release - Covidien',
#  'Fentanyl sublingual - iX Biopharma',
#  'Davasaicin',
#  'Fentanyl needle-free injectable - Glide/Endo',
#  'Oxycodone controlled release - Cassava Sciences',
#  'Dapitant',
#  'Tramadol extended release - Cipher Pharmaceuticals',
#  'Tilnoprofen arbamel',
#  'Liquid filled aspirin capsule - PLx Pharma',
#  'Hydrocodone/ibuprofen - Kowa Pharmaceuticals America',
#  'CGX 1160',
#  'Cannabidiol/dronabinol- Beckley Canopy Therapeutics',
#  'CJC 1008',
#  'Hydromorphone abuse-resistant - Acura Pharmaceuticals',
#  'Buprenorphine/naloxone - Aoxing Pharmaceutical Company',
#  'Oxycodone hydrochloride hydrate controlled-release - Daiichi Sankyo',
#  'Aspirin/omeprazole 650/20',
#  'Rufinamide - Novartis',
#  'Morphine oral - AbbVie',
#  'Buprenorphine/naloxone - Ology Bioservices',
#  'Alfadolone',
#  'Ziconotide - RIEMSER Arzeneimittel/TerSera Therapeutics',
#  'Dexsiometheptene mucate - Tonix Pharmaceuticals',
#  'BL 1832',
#  'Methadone - Teikoku Seiyaku',
#  'Morphine intranasal - Hospira',
#  'Anpirtoline',
#  'Pregabalin controlled release - Intellipharmaceutics',
#  'Buprenorphine intranasal - Vernalis',
#  'Morphine - Lannett Holdings',
#  'Paracetamol intravenous - Altan Pharma',
#  'Oxycodone/promethazine - Charleston Laboratories',
#  'VANH 36',
#  'Naproxen/pregabalin topical - XGene Pharmaceutical',
#  'Cannabidiol/tetrahydrocannabinol - Zelira Therapeutics',
#  'Tramadol orodispersible - Ethypharm',
#  'Hydrocodone controlled-release - Currax Pharmaceuticals',
#  'Fentanyl injection - Daiichi Sankyo Company',
#  'Fentanyl buccal - BioDelivery Sciences/TTY Biopharm',
#  'Licostinel',
#  'Buprenorphine/naloxone sublingual - Benuvia Therapeutics',
#  'MH 15E',
#  'VBY 129',
#  'Tapentadol controlled-release - Grunenthal/Janssen Research & Development/Ortho-McNeil',
#  'Levorphanol - Relmada Therapeutics',
#  'Flusalazine - GNT Pharma',
#  'Tramadol orally disintegrating tablets - Athena Drug Delivery Solutions',
#  'Abuse resistant oxycodone immediate release - Grunenthal',
#  'Oxycodone hydrochloride - SpecGx',
#  'XEN 403',
#  'Fentanyl buccal - Generex Biotechnology',
#  'Dextromethorphan/methadone - Endo',
#  'TV 46139',
#  'Tramadol - Aytu BioPharma',
#  'ONO 8711',
#  'Benzhydrocodone - KemPharm',
#  'Nefopam topical cream - ScarX Therapeutics',
#  'Pregabalin controlled release - Mapi Pharma',
#  'Fentanyl transdermal - Janssen Pharmaceutical KK',
#  'Fentanyl transdermal patch - Lavipharm',
#  'Tramadol - TheraQuest Biosciences',
#  'Relugolix - Myovant/Takeda',
#  'Dextromethadone - Cornell University/Relmada Therapeutics',
#  'Dronabinol/palmitoylethanolamide - SciSparc',
#  'Celecoxib - Astellas Pharma/Pfizer',
#  'CEP 28190',
#  'Ketoprofen transdermal - IDEA AG',
#  'Fentanyl transdermal patch - Clexio Biosciences',
#  'Fentanyl transdermal - 3M Drug Delivery Systems/Purdue Pharma',
#  'Trefentanil',
#  'NGX 5020',
#  'Propiram',
#  'GPI 5693',
#  'Hydrocodone/paracetamol/alvimopan',
#  'Nitroglycerin topical - Kyowa Kirin International',
#  'Diclofenac rectal - CeNeS',
#  'Morphine hydrochloride sustained release - Takeda',
#  'Ultramorph',
#  'Diclofenac - Benuvia Therapeutics',
#  'Prostaglandin E EP4 receptor antagonist - Eli Lilly and Company',
#  'Hydromorphone extended release - Teva Pharmaceutical Industries',
#  'VX 961',
#  'Syn 1001',
#  'AN 982',
#  'Buprenorphine oral - Orexo',
#  'Fentanyl sublingual - Ethypharm',
#  'Prosaptide TX14 A',
#  'Hydromorphone/promethazine - Charleston Laboratories',
#  'Alfentanil sublingual - Orexo',
#  'AQU 005',
#  'CP 122721',
#  'Vedaclidine',
#  'SYN 116',
#  'Fentanyl transmucosal - Endo',
#  'CJ 15161',
#  'Morphine inhalation - Aradigm Corporation',
#  'Paracetamol ODT - Adare Pharmaceuticals',
#  'Neramexane - Merz Pharma',
#  'Tramadol controlled release - e-Therapeutics',
#  'ONO 9902',
#  'Oxycodone/naloxone sustained release - Shandong Luye Pharmaceutical',
#  'JNJ 38488502',
#  'Morphine-6-glucuronide - ML Laboratories',
#  'Fentanyl transmucosal - Teva Pharmaceutical Industries',
#  'Esomeprazole/meloxicam - Axsome Therapeutics',
#  'Clonidine gel - Curatek Pharmaceuticals',
#  'Oxycodone controlled-release - Intellipharmaceutics',
#  'DPI 3290',
#  'Amitriptyline/oxymetazoline/ketoprofen - Omeros Corporation',
#  "Fentanyl - Alexza Pharmaceuticals/Lee's Pharmaceutical",
#  'Hydromorphone controlled-release - Avadel Pharmaceuticals',
#  'Butorphanol intranasal',
#  'PTI 901',
#  'GW 275919',
#  'Oxycodone controlled release - Elite Pharmaceuticals',
#  'BL 1834',
#  'NKTR 171',
#  'SR 144190',
#  'Oxycodone/paracetamol/dextromethorphan - Endo',
#  'Oxycodone controlled-release - GL PharmTech',
#  'ReN 1869',
#  'Oxycodone extended-release/abuse-resistant - Collegium Pharmaceutical',
#  'Ruzadolane',
#  'ZTL 103',
#  'Piroxicam betadex - Chiesi',
#  'Fentanyl transdermal - Luye Pharma',
#  'Codeine - Hikma Pharmaceuticals',
#  'Morphine transdermal - Avecho Biotechnology',
#  'Naproxen/pregabalin conjugate - Xgene Pharmaceutical',
#  'Morphine intranasal - Adhera Therapeutics',
#  'Fentanyl inhalation - Aradigm Corporation',
#  'Tramadol - Bausch Health Companies \\',
#  'JTC 801',
#  'Opioid analgesic controlled-release - Akela Pharma',
#  'RO 158081',
#  'Valnivudine - Hepion Pharmaceuticals',
#  'Morphine rectal - CeNeS Pharmaceuticals',
#  'Cannabidiol - ANANDA Scientific',
#  'RGH 478',
#  'CereCRIB',
#  'XEN 2174',
#  'Diclofenac sodium transdermal patch - Hisamitsu Pharmaceuticals',
#  'PTI 601',
#  'CGX 1007',
#  "Memantine - Children's Medical Center Corporation/Merz Pharma",
#  'Tramadol - Nippon Shinyaku/Janssen Pharmaceutica',
#  'Sodium metaarsenite - Komipharm International',
#  'Hydromorphone transdermal - Altea Therapeutics',
#  'ZD 9379',
#  'Buprenorphine transdermal - Samyang',
#  'T 3788']
